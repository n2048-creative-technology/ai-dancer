# %%
import tensorflow as tf
from tensorflow.keras import layers

import numpy as np
import matplotlib.pyplot as plt
import os

# %%
## IMPORT DATA
dataset = tf.data.TextLineDataset('data/2019-10-04_12-03-39.mp4-57.mp4.txt')

# %%
## Format X,Y sets
data = []
lengths = []
for line in dataset.take(10000):
    l = line.numpy().split(' ')
    if len(l) == 59:
        data.append(l)
    
files = [d[0] for d in data]
x = [np.array(d[1:25], dtype = float) for d in data]
y = [ np.array((d[25::2],d[26::2]), dtype=float).transpose() for d in data]

print (np.shape(x), np.shape(y))

# %%
# translate keypoints based on  nose position (origin = nose at first frame)
origin = y[0][0]
ty = y - origin
np.shape(ty)
# Out:
# (23, 17, 2)

# %%
y[0][0][0]  # x position of nose on first frame. 
# y[10][5][1] # y poosition of left Shoulder on frame #9
# Out:
# 6.648

# %%
X

# %%
model = tf.keras.Sequential()

model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True), 
                               input_shape=(23, 24)))
model.add(layers.Bidirectional(layers.LSTM(32)))
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# bidirectional (Bidirectional (None, 23, 128)           45568
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# ...
# Total params: 87,434
# Trainable params: 87,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.random.random((23, 24)).astype(np.float32)
np.random.random((23, 17, 2)).astype(np.float32)
# Out:
# array([[[7.99198329e-01, 2.35392481e-01],
#         [6.10410988e-01, 9.58141923e-01],
#         [4.03759778e-01, 2.74295956e-02],
#         [8.57913256e-01, 9.32893991e-01],
#         [1.98158786e-01, 1.36842445e-01],
#         [5.88336110e-01, 1.74941629e-01],
#         [8.68575498e-02, 1.70604318e-01],
#         [7.09155381e-01, 8.68387759e-01],
#         [1.54509649e-01, 6.10476732e-01],
#         [4.55963522e-01, 6.73989296e-01],
#         [5.78531623e-01, 4.66056645e-01],
#         [5.74151814e-01, 2.77338356e-01],
#         [8.60225439e-01, 8.69186521e-01],
#         [5.83794832e-01, 1.70069307e-01],
#         [4.49316323e-01, 8.40319574e-01],
#         [1.45607799e-01, 8.34956765e-01],
#         [5.02368212e-01, 6.52727664e-01]],
#
#        [[5.85354269e-01, 5.12990117e-01],
#         [3.70715588e-01, 8.96596313e-01],
#         [8.23894620e-01, 7.94877887e-01],
#         [3.88477772e-01, 4.01514053e-01],
#         [2.20779721e-02, 8.20950270e-01],
# ...
